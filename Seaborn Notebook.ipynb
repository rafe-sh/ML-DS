# %% [markdown]
# ## Contents
#
# * [Scatter Plot](#Scatter-Plot)
#
# * [Distribution Plots](#Distribution-Plots)
#  1. [Rugplot](#1.-rugplot())
#  2. [Displot](#2.-displot())
#  3. [Histplot](#3.-histplot())
#  4. [Kdeplot](#4.-kdeplot())
#
# * [Categorical Plots](#Categorical-Plots)
#  1. [Countplot](#1.-countplot())
#  2. [Barplot](#2.-barplot())
#
# * [Categorical Plots - Distribution within Categories](#Categorical-Plots---Distribution-within-Categories)
#  1. [Boxplot](#1.-boxplot())
#  2. [Violinplot](#2.-violinplot())
#  3. [Advanced Plots](#3.-Advanced-plots)
#    1. [Swarmplot](#3.1-swarmplot())
#    2. [Boxenplot (letter-value plot)](#3.2-boxenplot-(letter-value-plot))
#
# * [Comparison Plots](#Comparison-Plots)
#  1. [jointplot](#1.-jointplot())
#  2. [pairplot](#2.-pairplot())
#
# * [Grids](#Grids)
#  1. [Catplot](#1.catplot())
#  2. [PairGrid](#2.PairGrid())
#  3. [FacetGrid](#3.FacetGrid())
#
# * [Matrix Plots](#Matrix-Plots)
#  1. [Heatmap](#1.heatmap())
#  2. [Clustermap](#2.clustermap())
#
# * [Seaborn Exercises](#Seaborn-Exercises)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Scatter Plot

# %%
df = pd.read_csv('dm_office_sales.csv')

# %%
df.sample(5)
# Out:
#             division  level of education  training level  work experience  \
# 847         printers         high school               2                4
# 23          printers   bachelor's degree               1                8
# 652  office supplies        some college               2                7
# 77   office supplies  associate's degree               2                3
# 226  office supplies        some college               2                4
#
#      salary   sales
# 847   71895  305898
# 23   101064  400527
# 652   99365  416423
# 77    75155  311547
# 226   80981  314799

# %%
plt.figure(figsize=(9,4),dpi=100)

sns.scatterplot(x='salary', y='sales', data=df, hue='division', palette='magma', style='level of education',
               size='work experience', alpha=0.5)

plt.legend(loc=(1.05,.05), prop={'size': 6})

# %% [markdown]
# # Distribution Plots

# %%
# iF I want a hist plot without displot

plt.hist(df['salary'], bins=50, color='purple', alpha=0.6);

# %% [markdown]
# ## 1. rugplot()

# %%
plt.figure(figsize=(8,4), dpi=100)

sns.rugplot(data=df, x='salary', height=0.5, hue='work experience', palette='viridis', expand_margins=True)

# plt.legend(loc=0)
# Out:
# <AxesSubplot:xlabel='salary'>

# %% [markdown]
# ## 2. displot()
# it has more things that will be practiced later

# %%
# Background
# sns.set(style='white')

sns.displot(df, x='salary', bins=30, color='green',
            edgecolor='white', lw=1, ls='--',
            kde=True, rug=True)

# %%
# Background
# sns.set(style='ticks')

sns.displot(df, x='salary', hue='division', kde=True)

# %%
sns.displot(df, x='salary', y = 'sales', )

# %% [markdown]
# ## 3. histplot()

# %%
sns.histplot(df[['salary','sales']], bins=40, kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(df['salary'], bins=50, kde=True)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
sns.histplot(x=df['salary'], y= df['sales'])
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ## 4. kdeplot()

# %%
sns.kdeplot(df['salary'], shade=True, color='red')
sns.kdeplot(df['salary'], shade=False, color='blue', bw_adjust=0.3, ls='--')
sns.kdeplot(df['salary'], shade=False, color='green', bw_adjust=0.1, lw=0.6, ls='--')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
sns.kdeplot(df['salary'], shade=True, color='red', clip=[60000,120000])
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
sns.kdeplot(df['salary'], df['sales'], shade=True, color='purple')
# Out:
# C:\Users\rafes\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# ## 1. countplot()

# %%
plt.figure(figsize=(8,4), dpi=200)

sns.countplot(x=df['division'], hue=df['level of education'], palette='Set1', orient='v', )

plt.tight_layout()
plt.legend(loc=(1.05,0.5))

# %% [markdown]
# ## 2. barplot()

# %%
plt.figure(figsize=(12,6), dpi=200)

sns.barplot(data=df, x='division', y= 'salary', palette='Set1',
            hue='level of education', 
            estimator=np.mean, 
            ci='sd', errcolor='black', errwidth=1)

plt.legend(loc=(1.05,0.5))

# %% [markdown]
# # Categorical Plots - Distribution within Categories

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
df.sample(5)
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 815    male        group B            some high school  standard
# 192  female        group B            some high school  standard
# 711  female        group E            some high school  standard
# 479    male        group E          associate's degree  standard
# 226  female        group C                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 815               completed          94             86             87
# 192                    none          62             64             66
# 711               completed          80             85             85
# 479                    none          76             71             67
# 226                    none          72             72             71

# %% [markdown]
# ## 1. boxplot()

# %%
plt.figure(dpi=80)

sns.boxplot(x='math score', y='gender' , data=df, width=0.7,
            hue='test preparation course')

plt.legend(loc=(1.05,0.5))

# %%
plt.figure(figsize=(12,4) ,dpi=80)

sns.boxplot(x='parental level of education', y='math score' , data=df,
            palette='Set2', width=0.5, saturation=1, whis=1.5, fliersize=2, dodge=True,
            hue='test preparation course')

plt.legend(loc=(1.05,0.5))

# %% [markdown]
# ## 2. violinplot()

# %%
plt.figure(dpi=80)

sns.violinplot(x= 'test preparation course', y='math score', data=df, palette='Set2', saturation=1,
               split=True, bw=0.2, width=0.5, 
               hue='gender', inner='quartile')

plt.legend(loc=(1.05,0.5))

# %%
plt.figure(dpi=80)

sns.violinplot(x= 'math score', y='test preparation course', data=df, palette='Set2', saturation=1,
               split=True, bw=0.2, width=0.8, 
               hue='gender', inner='box')

plt.legend(loc=(1.05,0.5))

# %% [markdown]
# ## 3. Advanced plots
# May require to educate the viewer with how the plot is actually constructed

# %% [markdown]
# ### 3.1 swarmplot()

# %%
plt.figure(dpi=100)

sns.swarmplot(x= 'math score', y = 'test preparation course', data=df, size=2,
              palette='Set2', dodge=True, alpha=1,
              hue='gender')

plt.legend(loc=(1.05,0.5))

# %% [markdown]
# ### 3.2 boxenplot (letter-value plot)
# Official Paper on this plot: https://vita.had.co.nz/papers/letter-value-plot.html

# %%
plt.figure(dpi=100)

#k_depth ['proportion', 'tukey', 'trustworthy', 'full']

sns.boxenplot(x='math score', y='gender', data=df, saturation=1, palette='Set2', width=0.5,
             hue='test preparation course', k_depth='tukey')

plt.legend(loc=(1.05,0.5))

# %%
plt.figure(dpi=100, figsize=(5,3))
sns.boxenplot(x='race/ethnicity',y='math score',data=df ,saturation=10, palette='Set2')
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='math score'>

# %% [markdown]
# # Comparison Plots

# %% [markdown]
# ## 1. jointplot()

# %%
sns.jointplot(x='math score', y='reading score', data=df, palette='Set2', kind='kde',
               height=6, ratio=5, space=0.2, hue='gender')

# %%
sns.jointplot(x='math score', y='reading score', data=df, color='#0bb88c', kind='hex',
               height=6, ratio=5, space=0.2)

# kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %% [markdown]
# ## 2. pairplot()

# %%
sns.pairplot(df, hue='gender', palette='Set2', kind='kde', corner=True)

# %%
s = sns.pairplot(df, hue='gender', palette='Set2', kind='hist', diag_kind='hist', height=3)
s.map_lower(sns.kdeplot)

# %% [markdown]
# # Grids

# %% [markdown]
# ## 1.catplot()

# %%
# Kind Options are: “point”, “bar”, “strip”, “swarm”, “box”, “violin”, or “boxen”

sns.catplot(x='math score', y='test preparation course', data=df, kind='violin', hue='gender', 
            split=True, palette='Set2', inner='quartile',
            col='parental level of education', row='lunch',
            height=6)

# %%
sns.catplot(x='math score', y='test preparation course', data=df, kind='box',
           hue='gender', 
           col='parental level of education', 
           height=4)

# %% [markdown]
# ## 2.PairGrid()

# %%
p = sns.PairGrid(df, hue='gender', palette='Set2')
p = p.map_upper(sns.scatterplot, s=10)
p = p.map_diag(sns.histplot,  edgecolor='w')
p = p.map_lower(sns.kdeplot)
p = p.add_legend();

# %% [markdown]
# ## 3.FacetGrid()

# %%
g = sns.FacetGrid(data=df,col='test preparation course',row='lunch', hue='gender', height=6)
g = g.map(plt.scatter, "math score", "reading score", edgecolor="w", s=40)
g.add_legend()
plt.subplots_adjust(hspace=0.2, wspace=0.1)

# %% [markdown]
# # Matrix Plots

# %%
df = pd.read_csv('country_table.csv')

# %%
df = df.set_index('Countries')
df
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
# OCEANIA                              16.235           6.788           78.880
# WORLD                                17.963           7.601           72.766
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# LATIN AMERICA AND THE CARIBBEAN                 14.570         8.89
# NORTHERN AMERICA                                 5.563         6.11
# OCEANIA                                         16.939        12.79
# WORLD                                           27.492        10.36

# %% [markdown]
# ## 1.heatmap()

# %%
sns.heatmap(df, cmap='magma')
# life expectency is in another order so we omit it
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
ratedf = df.drop('Life expectancy', axis=1)

# %%
plt.figure(dpi=200)

sns.heatmap(ratedf, lw=0.5, annot=True, annot_kws={"size": 8}, cmap='magma', center=25)

plt.xticks(fontsize= 8)
plt.yticks(fontsize= 8);

# %% [markdown]
# ## 2.clustermap()

# %%
sns.clustermap(ratedf, cmap='magma', center=25, annot=True, annot_kws={"size": 10}, lw=0.5,
               method='average', figsize=(12, 10), cbar_pos=(0.9, 0.8, 0.05, 0.18),)
plt.savefig('cluster.jpg', dpi=200)

# %%
sns.clustermap(ratedf, cmap='magma', annot=True, col_cluster=False)

# %% [markdown]
# # Seaborn Exercises

# %%
df = pd.read_csv('application_record.csv')

# %%
df.sample(4)
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 63594   5213344           F            N               N             1
# 388665  6643131           F            N               Y             0
# 389375  6651349           F            N               N             0
# 95564   6294006           F            Y               N             1
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 63594           180000.0    State servant               Higher education
# 388665          157500.0          Working  Secondary / secondary special
# 389375          157500.0    State servant  Secondary / secondary special
# 95564           135000.0          Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS    NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 63594                Married  Municipal apartment      -11539          -4856
# 388665                 Widow    House / apartment      -18597          -7700
# 389375  Single / not married    House / apartment      -13812          -5349
# 95564                Married    House / apartment      -11952          -2293
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 63594            1                1           0           0  Security staff
# 388665           1                1           1           0   Cooking staff
# 389375           1                0           0           0  Medicine staff
# 95564            1                0           0           0        Laborers
#
#         CNT_FAM_MEMBERS
# 63594               3.0
# 388665              1.0
# 389375              1.0
# 95564               3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
#  15  FLAG_EMAIL           438557 non-null  int64
#  16  OCCUPATION_TYPE      304354 non-null  object
#  17  CNT_FAM_MEMBERS      438557 non-null  float64
# dtypes: float64(2), int64(8), object(8)
# memory usage: 60.2+ MB

# %%
# For Employed people => Days Employed vs Birthday

# %%
dfem = df[df['DAYS_EMPLOYED']<0]

# %%
dfem['DAYS_EMPLOYED'] = np.vectorize(lambda x: abs(x))(dfem['DAYS_EMPLOYED'])
dfem['DAYS_BIRTH'] = np.vectorize(lambda x: abs(x))(dfem['DAYS_BIRTH'])
# Out:
# C:\Users\rafes\AppData\Local\Temp/ipykernel_13684/1355657277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfem['DAYS_EMPLOYED'] = np.vectorize(lambda x: abs(x))(dfem['DAYS_EMPLOYED'])
# C:\Users\rafes\AppData\Local\Temp/ipykernel_13684/1355657277.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfem['DAYS_BIRTH'] = np.vectorize(lambda x: abs(x))(dfem['DAYS_BIRTH'])

# %%
plt.figure(figsize=(8,6), dpi=100)
sns.scatterplot(x='DAYS_BIRTH', y= 'DAYS_EMPLOYED', data=dfem, alpha=0.01, linewidth=0, s=10)
# Out:
# <AxesSubplot:xlabel='DAYS_BIRTH', ylabel='DAYS_EMPLOYED'>

# %%
dff = df['DAYS_BIRTH']*-1 //365

# %%
plt.figure(figsize=(10,4), dpi=100)

f = sns.countplot(x=dff, color='pink', saturation=0.9, edgecolor='black', linewidth=0.8)

f.set_xticks([0,9,19,29,39,49])
f.set_xticklabels([20,30,40,50,60,70])

plt.tight_layout()

# %%
# For the bottom half of income earners

# %%
df1 = df.nsmallest(int(len(df)/2), 'AMT_INCOME_TOTAL')[['AMT_INCOME_TOTAL', 'NAME_FAMILY_STATUS', 'FLAG_OWN_REALTY']]

# %%
plt.figure(figsize=(12,4))

sns.boxplot(x='NAME_FAMILY_STATUS', y = 'AMT_INCOME_TOTAL', data=df1, hue='FLAG_OWN_REALTY', width=0.7, palette='Set2')

plt.title('Income Totals per Family Status for Bottom Half of Earners')
plt.legend(loc=(1.05,0.5), title='FLAG_OWN_REALTY')

# %%
# Heatmap Correlation

# %%
dff = df.drop('FLAG_MOBIL', axis=1).corr()

# %%
dff
# Out:
#                         ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  \
# ID                1.000000     -0.005178          0.011179   -0.004994
# CNT_CHILDREN     -0.005178      1.000000          0.019177    0.349088
# AMT_INCOME_TOTAL  0.011179      0.019177          1.000000    0.053775
# DAYS_BIRTH       -0.004994      0.349088          0.053775    1.000000
# DAYS_EMPLOYED    -0.002467     -0.241535         -0.141291   -0.617908
# FLAG_WORK_PHONE  -0.023319      0.038418         -0.033635    0.171829
# FLAG_PHONE       -0.018992     -0.038266          0.004444   -0.037984
# FLAG_EMAIL        0.032875      0.028457          0.112139    0.096752
# CNT_FAM_MEMBERS  -0.001862      0.884781          0.011454    0.306179
#
#                   DAYS_EMPLOYED  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# ID                    -0.002467        -0.023319   -0.018992    0.032875
# CNT_CHILDREN          -0.241535         0.038418   -0.038266    0.028457
# AMT_INCOME_TOTAL      -0.141291        -0.033635    0.004444    0.112139
# DAYS_BIRTH            -0.617908         0.171829   -0.037984    0.096752
# DAYS_EMPLOYED          1.000000        -0.232208    0.004868   -0.074372
# FLAG_WORK_PHONE       -0.232208         1.000000    0.290066   -0.060915
# FLAG_PHONE             0.004868         0.290066    1.000000   -0.001170
# FLAG_EMAIL            -0.074372        -0.060915   -0.001170    1.000000
# CNT_FAM_MEMBERS       -0.234373         0.049777   -0.024213    0.022054
#
#                   CNT_FAM_MEMBERS
# ID                      -0.001862
# CNT_CHILDREN             0.884781
# AMT_INCOME_TOTAL         0.011454
# DAYS_BIRTH               0.306179
# DAYS_EMPLOYED           -0.234373
# FLAG_WORK_PHONE          0.049777
# FLAG_PHONE              -0.024213
# FLAG_EMAIL               0.022054
# CNT_FAM_MEMBERS          1.000000

# %%
plt.figure(figsize=(7,7), dpi=80)

sns.heatmap(dff, cmap='viridis')

plt.xticks(fontsize= 8)
plt.yticks(fontsize= 8);
